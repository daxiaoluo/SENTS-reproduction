# %%
import ucca
import xml.etree.ElementTree as ET
# !pip list
# Out:
# Package                  Version
# ------------------------ ---------
# anaconda-client          1.6.14
# anaconda-navigator       1.8.7
# backcall                 0.1.0
# boto                     2.48.0
# Bottleneck               1.2.1
# certifi                  2018.4.16
# cffi                     1.11.5
# chardet                  3.0.4
# click                    6.7
# cloudpickle              0.5.3
# clyent                   1.2.2
# collective.checkdocs     0.2
# colorama                 0.3.9
# conda                    4.5.5
# conda-build              3.10.5
# conda-verify             2.0.0
# ConfigArgParse           0.13.0
# contextlib2              0.5.5
# cryptography             2.2.2
# cycler                   0.10.0
# cymem                    1.31.2
# Cython                   0.28.2
# cytoolz                  0.8.2
# dask                     0.17.5
# datashape                0.5.4
# decorator                4.3.0
# dill                     0.2.8.2
# ...

# %%
XML_file = 'example_0.xml'
tree = ET.parse (XML_file)
root = tree.getroot()

passage = ucca.convert.from_site (root)
#ucca.visualization.draw (passage)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-a00bd9017db5> in <module>()
#       3 root = tree.getroot()
#       4
# ----> 5 passage = ucca.convert.from_site (root)
#       6 #ucca.visualization.draw (passage)
#
# AttributeError: module 'ucca' has no attribute 'convert'
